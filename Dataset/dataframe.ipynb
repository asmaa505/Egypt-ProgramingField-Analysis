# %%
import pandas as pd

df = pd.read_csv('Web-Developers-Salaries-Egypt-2024.csv')
df
# Out:
#                    Title  Salary  Years of Experiences  Work Hour Work Type  \
# 0         .Net Developer   15000                     1  Full Time    Hybird
# 1         .Net Developer  311050                     2  Full Time    Hybird
# 2         .Net Developer   15000                     1  Full Time    Hybird
# 3         .Net Developer   30000                     2  Full Time    Hybird
# 4         .Net Developer   54000                     3  Full Time    Hybird
# ..                   ...     ...                   ...        ...       ...
# 191        Web Developer    5000                     0  Full Time   On Site
# 192        Web Developer    9000                     1  Full Time  Remotley
# 193  Wordpress Developer   14000                     4  Full Time    Hybird
# 194  Wordpress Developer   30000                     3  Full Time   On Site
# 195  Wordpress Developer   40000                     3  Full Time  Remotley
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 196 non-null    str
#  1   Salary                196 non-null    int64
#  2   Years of Experiences  196 non-null    int64
#  3   Work Hour             196 non-null    str
#  4   Work Type             196 non-null    str
#  5   What Is your Company  196 non-null    str
#  6   City of Company site  196 non-null    str
# dtypes: int64(2), str(5)
# memory usage: 10.8 KB

# %%
df2 = pd.read_csv('Cleaned_Wuzzuf_Jobs.csv')
df2
# Out:
#                                     name            company  \
# 0             Human Resources Generalist            Options
# 1     Sales in freight forwarder company      MIF Logistics
# 2         Senior Real Estate Sales Agent           BrokMark
# 3                        Product Manager            Valeurs
# 4                 Recruitment Specialist  Outsourcing Skill
# ...                                  ...                ...
# 7861               Laravel PHP Developer       Confidential
# 7862                      UI UX Designer       Confidential
# 7863                        AI evaluator         Translated
# 7864                      Sales Engineer      ODA Furniture
# 7865                  Tendering Engineer              INGAZ
#
#                         location                         type  \
# 0       Mohandessin, Giza, Egypt           Full Time, On-site
# 1       Obour City, Cairo, Egypt           Full Time, On-site
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 196 non-null    str
#  1   Salary                196 non-null    int64
#  2   Years of Experiences  196 non-null    int64
#  3   Work Hour             196 non-null    str
#  4   Work Type             196 non-null    str
#  5   What Is your Company  196 non-null    str
#  6   City of Company site  196 non-null    str
# dtypes: int64(2), str(5)
# memory usage: 10.8 KB
