# %%
# dataset 1
import pandas as pd

df1 = pd.read_csv('Web-Developers-Salaries-Egypt-2024.csv')
df1
# Out:
#                    Title  Salary  Years of Experiences  Work Hour Work Type  \
# 0         .Net Developer   15000                     1  Full Time    Hybird
# 1         .Net Developer  311050                     2  Full Time    Hybird
# 2         .Net Developer   15000                     1  Full Time    Hybird
# 3         .Net Developer   30000                     2  Full Time    Hybird
# 4         .Net Developer   54000                     3  Full Time    Hybird
# ..                   ...     ...                   ...        ...       ...
# 191        Web Developer    5000                     0  Full Time   On Site
# 192        Web Developer    9000                     1  Full Time  Remotley
# 193  Wordpress Developer   14000                     4  Full Time    Hybird
# 194  Wordpress Developer   30000                     3  Full Time   On Site
# 195  Wordpress Developer   40000                     3  Full Time  Remotley
#
#                    What Is your Company City of Company site
# 0                              Egyptian           Alexandria
# 1                              Egyptian                Cairo
# 2                              Egyptian                 Giza
# 3                              Egyptian             Mansoura
# 4                              Egyptian             un-known
# ..                                  ...                  ...
# 191                            Egyptian                Cairo
# 192      Not Egyptian but site in egypt                  Ksa
# 193                            Egyptian                Cairo
# 194                            Egyptian                Cairo
# 195  Not Egyptian and site out of egypt                  Uae
#
# [196 rows x 7 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 196 non-null    object
#  1   Salary                196 non-null    int64
#  2   Years of Experiences  196 non-null    int64
#  3   Work Hour             196 non-null    object
#  4   Work Type             196 non-null    object
#  5   What Is your Company  196 non-null    object
#  6   City of Company site  196 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 10.8+ KB

# %%
df2 = pd.read_csv('wuzzuf_jobs.csv')
df2
# Out:
#      Unnamed: 0                   TimeStamp                    Title  \
# 0             0  2024-02-19 20:09:36.277000        Dotnet Developer
# 1             1  2024-02-19 20:10:43.450000             Android deve
# 2             2  2024-02-19 20:23:24.387000        Android Developer
# 3             3  2024-02-19 20:27:08.358000         DevOps Engineer
# 4             4  2024-02-19 20:31:36.432000                    Java
# ..          ...                         ...                      ...
# 903        1323  2024-03-07 10:04:23.532000      Software developer
# 904        1324  2024-03-07 12:25:44.049000    Embedded SW Engineer
# 905        1325  2024-03-07 12:52:53.200000           Php developer
# 906        1329  2024-03-08 19:01:07.101000  Seniors interior design
# 907        1330       10:10:49 ص 2024/03/02          DevOps Engineer
#
#     Years of Experiences  Salary       Date of Salary What Is your Company  \
# 0                       2   8000  2024-02-01 00:00:00             Egyption
# 1                     NaN   6000  2024-02-06 00:00:00             Egyption
# 2                       1  10000  2024-02-20 00:00:00             Egyption
# 3                1 month   10000  2024-02-19 00:00:00             Egyption
# 4                       1  20000  2024-02-19 00:00:00             Egyption
# ..                    ...    ...                  ...                  ...
# 903                     4    45K  2024-02-01 00:00:00             Egyption
# 904                     0    10k  2024-03-01 00:00:00             Egyption
# 905                     1  10000  2024-03-01 00:00:00             Egyption
# 906                     7  19000  2024-01-01 00:00:00             Egyption
# 907                     1  29000  2024-03-03 00:00:00             Egyption
#
#     Work Type  Work Hour City of Company site
# 0      Hybird  Full Time                Cairo
# 1      Hybird  Full Time              Assiut
# 2      Hybird  Full Time                Cairo
# 3     On Site  Full Time              Assiut
# 4     On Site  Full Time                Cairo
# ..        ...        ...                  ...
# 903  Remotley  Full Time                Cairo
# 904   On Site  Full Time                cairo
# 905  Remotley  Full Time                Cairo
# 906  Remotley  Full Time                Cairo
# 907    Hybird  Full Time                cairo
#
# [908 rows x 10 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             908 non-null    int64
#  1   TimeStamp              908 non-null    object
#  2   Title                  908 non-null    object
#  3   Years of Experiences   907 non-null    object
#  4   Salary                 908 non-null    object
#  5   Date of Salary         908 non-null    object
#  6   What Is your Company   908 non-null    object
#  7   Work Type              908 non-null    object
#  8   Work Hour              908 non-null    object
#  9   City of Company site   816 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 71.1+ KB

# %%
# Integration
import pandas as pd

df1 = pd.read_csv("Web-Developers-Salaries-Egypt-2024.csv")
df2 = pd.read_csv("wuzzuf_jobs.csv")


df2.rename(columns={
    "Years of Experiences ": "Years of Experiences"
}, inplace=True)


df2.drop(columns=["Unnamed: 0", "TimeStamp"], inplace=True)


df = pd.concat([df1, df2], ignore_index=True)

# %%
# information about dataset after integration
rows, cols = df.shape
print("Rows:", rows)
print("Columns:", cols)
# Out:
# Rows: 1104
# Columns: 8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 1104 non-null   object
#  1   Salary                1104 non-null   object
#  2   Years of Experiences  1103 non-null   object
#  3   Work Hour             1104 non-null   object
#  4   Work Type             1104 non-null   object
#  5   What Is your Company  1104 non-null   object
#  6   City of Company site  1012 non-null   object
#  7   Date of Salary        908 non-null    object
# dtypes: object(8)
# memory usage: 69.1+ KB

# %%
df.head(10)
# Out:
#             Title  Salary Years of Experiences  Work Hour Work Type  \
# 0  .Net Developer   15000                    1  Full Time    Hybird
# 1  .Net Developer  311050                    2  Full Time    Hybird
# 2  .Net Developer   15000                    1  Full Time    Hybird
# 3  .Net Developer   30000                    2  Full Time    Hybird
# 4  .Net Developer   54000                    3  Full Time    Hybird
# 5  .Net Developer    9000                    1  Full Time    Hybird
# 6  .Net Developer  128000                    4  Full Time    Hybird
# 7  .Net Developer   60000                    6  Full Time    Hybird
# 8  .Net Developer   45000                    3  Full Time    Hybird
# 9  .Net Developer   15000                    1  Full Time    Hybird
#
#              What Is your Company City of Company site Date of Salary
# 0                        Egyptian           Alexandria            NaN
# 1                        Egyptian                Cairo            NaN
# 2                        Egyptian                 Giza            NaN
# 3                        Egyptian             Mansoura            NaN
# 4                        Egyptian             un-known            NaN
# 5  Not Egyptian but site in egypt                Benha            NaN
# 6  Not Egyptian but site in egypt                Cairo            NaN
# 7  Not Egyptian but site in egypt                Dubai            NaN
# 8  Not Egyptian but site in egypt                  Ksa            NaN
# 9  Not Egyptian but site in egypt    Maadi/Cairo , Ksa            NaN

# %% [markdown]
# ## Location Filtering
# - Removed non-Egypt records based on keywords (e.g., KSA, Dubai, USA, UK, etc.)
# - Standardized city names:
#   - Converted to lowercase
#   - Removed extra spaces

# %%
df_egypt = df[~df["City of Company site"].str.lower().str.contains("ksa|dubai|kuwait|texas|california|canada|bahrain|oman|jeddah|riyadh|saudi|usa|uk|germany|france",
    na=False)]
df_egypt["city of company site"] = (
    df_egypt["City of Company site"]
    .astype(str)
    .str.lower()
    .str.strip()
)
df=df_egypt.copy(
)
# Out:
# C:\Users\Ruof\AppData\Local\Temp\ipykernel_13548\4021248258.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_egypt["city of company site"] = (

# %% [markdown]
# ## Salary Statistics Before Cleaning & Outlier Handling
#
# This section presents the raw statistical summary of salaries by job title before applying advanced cleaning, normalization, and outlier handling.
#
# ---
#
# ## Key Observations
#
# ### 1. Salary levels across roles
# - Technical roles such as Backend, Frontend, and Full Stack Developers show relatively higher average salaries compared to non-technical roles.
# - Lower-paying roles include Graphic Designer, Pharmacist, and Accountant.
#
# ---
#
# ### 2. Difference between mean and median
# - In most job titles, the mean is higher than the median.
# - This suggests that some higher values already exist in the dataset and influence the average.
#
# ---
#
# ### 3. Distribution shape (skewness)
# - Many roles show positive skewness.
# - This indicates that salaries are not evenly distributed and are slightly concentrated toward lower or mid values with some higher observations.
#
# ---
#
# ### 4. Variability in salaries
# - Standard deviation varies across roles.
# - Technical roles show higher variability compared to non-technical roles, indicating differences in experience levels and job responsibilities.
#
# ---
#
# ### 5. Salary range (min–max)
# - There is already a noticeable gap between minimum and maximum salaries within several job titles.
# - This suggests early presence of variability in compensation even before cleaning.
#
# ---
#
# ## Conclusion
# The initial dataset already shows meaningful patterns in salary distribution:
# - Clear differences between job roles
# - Presence of variability within the same role
# - Early signs of skewed distributions
#
# This stage represents the raw structure of the data before further refinement and outlier treatment.

# %%
df.columns = df.columns.str.strip().str.lower()

df["title"] = df["title"].astype(str).str.lower().str.strip()
df["title"] = df["title"].replace("nan", "unknown")

df["salary"] = pd.to_numeric(df["salary"], errors="coerce")

df = df.dropna(subset=["salary"])

df = df[df["salary"] > 1000]

result = df.groupby("title")["salary"].agg([
    "mean","median","skew","max","min","count","std","var"
])

result = result[result["count"] >= 5]

result = result.sort_values(by="count", ascending=False)

pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1000)

print(result)
# Out:
#                                    mean   median      skew       max      min  count           std           var
# title
# .net developer             34652.564103  16000.0  4.072521  311050.0   5500.0     39  54088.731861  2.925591e+09
# frontend developer         44757.894737  20000.0  2.350803  252000.0   3500.0     38  57561.481263  3.313324e+09
# java developer             26225.000000  24250.0  1.312409   81000.0   4000.0     20  19385.103478  3.757822e+08
# php developer              27175.000000  13000.0  1.668813  100000.0   5000.0     20  29810.486940  8.886651e+08
# full stack developer       28842.105263  15000.0  2.370042  146000.0   5000.0     19  36408.581342  1.325585e+09
# flutter developer          11194.117647   8000.0  1.302798   27500.0   4000.0     17   7002.898560  4.904059e+07
# backend developer          36071.428571  21000.0  2.128432  139000.0   7000.0     14  36943.749936  1.364841e+09
# data analyst               12083.333333  12500.0  0.501880   24000.0   4500.0     12   5810.778908  3.376515e+07
# graphic designer            6590.909091   6500.0  0.164274   10000.0   3500.0     11   2142.640682  4.590909e+06
# full stack .net developer  23727.272727  15000.0  3.068236  120000.0   5000.0     11  32622.357086  1.064218e+09
# android developer          20700.000000  18000.0  1.683720   50000.0   7000.0     10  12156.845351  1.477889e+08
# nodejs developer           19100.000000  14000.0  3.030480   85000.0   7000.0     10  23416.281136  5.483222e+08
# data engineer              20222.222222  21000.0 -0.200049   30000.0  11000.0      9   6379.219736  4.069444e+07
# pharmacist                  4762.500000   4700.0  0.828539    8700.0   2000.0      8   2021.270817  4.085536e+06
# devops engineer            21862.500000  21000.0  0.060532   34000.0  10000.0      8   8277.842628  6.852268e+07
# accountant                  8950.000000   7750.0  1.682401   18000.0   5000.0      8   4219.681775  1.780571e+07
# software engineer          14975.000000  15000.0  0.490178   29000.0   2800.0      8   7119.741167  5.069071e+07
# data scientist             21714.285714  20000.0  0.302763   40000.0   7000.0      7  11441.361890  1.309048e+08
# machine learning engineer  21666.666667  19000.0  0.413484   35000.0  10000.0      6  11236.844160  1.262667e+08
# javascript developer       24800.000000  24000.0  0.196043   30000.0  20000.0      5   5019.960159  2.520000e+07
# full-stack developer       14600.000000  14000.0  0.280036   25000.0   5000.0      5   7092.249291  5.030000e+07
# medical representative      7700.000000   8000.0 -0.382400   10000.0   4500.0      5   2439.262184  5.950000e+06
# network engineer           18000.000000  10000.0  2.007235   43000.0  10000.0      5  14300.349646  2.045000e+08
# react developer            10400.000000  10000.0  1.492685   18000.0   6000.0      5   4560.701700  2.080000e+07
# software developer         16200.000000  12000.0  0.462552   27000.0   7000.0      5   9148.770409  8.370000e+07

# %% [markdown]
# ## Data Cleaning & Type Conversion
#
# - Converted **Salary** and **Work Hour** to numeric values
#   → Invalid entries were set to NaN
#
# - Cleaned **Years of Experiences**:
#   - Converted months to years
#   - Extracted numeric values from text
#
# - Checked data types and missing values
#
#  Missing values are identified

# %%
import numpy as np

def clean_exp(x):
    try:
        if isinstance(x, str):
            x = x.lower().strip()

            if "month" in x:
                num = float(x.split()[0])
                return num / 12

            # years
            elif "year" in x:
                return float(x.split()[0])

        return float(x)
    except:
        return np.nan
df["Salary"] = pd.to_numeric(df["Salary"], errors='coerce')
df["Years of Experiences"] = df["Years of Experiences"].apply(clean_exp)
df["Work Hour"] = pd.to_numeric(df["Work Hour"], errors='coerce')

print(df.dtypes)
df.isnull().sum()
# df.dropna(inplace=True)
# Out:
# title                     0
# salary                    0
# years of experiences      1
# work hour                 0
# work type                 0
# what is your company      0
# city of company site     64
# date of salary          157
# city of company site      0
# dtype: int64

# %% [markdown]
# ###  Cleaning "Years of Experiences"
#
# - Converted values to numeric format:
#   - Months → years
#   - Ranges (e.g., 2-4 years) → average
#   - Extracted numbers from text
#
# - Handled missing values:
#   - Replaced NaN with the median
#
#  Result: Clean and consistent experience values ready for analysis.

# %%
# deal with missing values

import numpy as np
import pandas as pd

def clean_exp(x):
    try:
        if isinstance(x, str):
            x = x.lower().strip()

            # months
            if "month" in x:
                return float(x.split()[0]) / 12

            # range
            elif "-" in x:
                parts = x.split("-")
                return (float(parts[0].strip()) + float(parts[1].split()[0].strip())) / 2

            # years
            else:
                return float(x.split()[0])

        return x

    except:
        return np.nan


col = "years of experiences"

df[col] = df[col].apply(clean_exp)

df[col] = pd.to_numeric(df[col], errors="coerce")

df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# #### percentage of missing values
#
# This code calculates the percentage of missing values in each column of the dataset.
#
# df.isnull() → returns True for missing values
# .mean() → computes the proportion of missing values per column
# * 100 → converts the result into percentage
# Output:
#
# Shows each column with its corresponding % of missing data.

# %%
missing_percent = df.isnull().mean() * 100
print(missing_percent)
# Out:
# title                    0.000000
# salary                   0.000000
# years of experiences     0.000000
# work hour                0.000000
# work type                0.000000
# what is your company     0.000000
# city of company site     7.494145
# date of salary          18.384075
# city of company site     0.000000
# dtype: float64

# %% [markdown]
# #### Explanation:
# - count() → counts non-null (valid) values
#
# - isnull().sum() → counts missing (null) values
#
# - Output:
#
# Number of filled values in the column
# Number of missing values in the column

# %%
# City of Company site column
print(f'count of not null values: {df["city of company site"].count()}\ncount of null values: {df["city of company site"].isnull().sum()}')
# Out:
# count of not null values: city of company site    790
# city of company site    854
# dtype: int64
# count of null values: city of company site    64
# city of company site     0
# dtype: int64

# %% [markdown]
# ## Date of Salary - Missing & Not Null Values
#
# This code shows the number of valid (non-null) and missing values in the **date of salary** column.
#
# - Output:
# Total valid entries in the column
# Total missing entries in the column

# %%
# Date of Salary colunm
print(f'count of not null values: {df["date of salary"].count()}\ncount of null values: {df["date of salary"].isnull().sum()}')
# Out:
# count of not null values: 697
# count of null values: 157

# %% [markdown]
# #### Handling Missing Values in Date Column
#
# This code converts the **date of salary** column into a proper datetime format and then handles missing values.
# - Result:
#
# The column becomes clean, fully formatted as datetime, with no missing values.

# %%
df["date of salary"] = pd.to_datetime(df["date of salary"], errors="coerce")
df["date of salary"] = df["date of salary"].ffill().bfill()

# %%
df["salary"] = df["salary"].fillna(df["salary"].median())

# %%
df.drop(columns=["work hour"], inplace=True)

# %%
df.isnull().sum()
# df.dropna(inplace=True)
# Out:
# title                    0
# salary                   0
# years of experiences     0
# work type                0
# what is your company     0
# city of company site    64
# date of salary           0
# city of company site     0
# dtype: int64

# %%
# Remove Duplication
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Outliers Detection (IQR Method)
#
# This code is used to clean the data, visualize distributions, and detect outliers using the IQR method.
#
# - Final Output
#
# All detected outliers are combined into one dataframe
# If found → displayed with total count
# If not → message: "No outliers found"
#
# - Result:
#
# This helps identify abnormal values in the dataset based on statistical distribution.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# =========================
# 1) CLEAN TITLE COLUMN
# =========================
df["title"] = df["title"].str.lower().str.strip().str.replace(r"\s+", " ", regex=True)

# =========================
# 2) NUMERICAL COLUMNS
# =========================
num_cols = df.select_dtypes(include=['number']).columns

# =========================
# 3) BOX PLOTS (BEFORE REMOVING ANYTHING)
# =========================
for col in num_cols:
    plt.figure(figsize=(6,4))
    df.boxplot(column=col)
    plt.title(f"Boxplot of {col}")
    plt.show()

for col in num_cols:
    plt.figure(figsize=(12,5))
    sns.boxplot(x="title", y=col, data=df)
    plt.xticks(rotation=90)
    plt.title(f"{col} by Title")
    plt.show()

# =========================
# 4) OUTLIERS DETECTION (IQR METHOD)
# =========================
all_outliers = []

for title, group in df.groupby("title"):
    for col in num_cols:
        Q1 = group[col].quantile(0.25)
        Q3 = group[col].quantile(0.75)
        IQR = Q3 - Q1

        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR

        outliers = group[(group[col] < lower) | (group[col] > upper)].copy()

        if not outliers.empty:
            outliers["outlier_column"] = col
            outliers["title_group"] = title
            all_outliers.append(outliers)

# =========================
# 5) FINAL OUTLIERS TABLE
# =========================
if all_outliers:
    outliers_df = pd.concat(all_outliers, ignore_index=True)
    print("TOTAL OUTLIERS FOUND:", len(outliers_df))
    display(outliers_df)
else:
    print("No outliers found")
# Out:
# TOTAL OUTLIERS FOUND: 55
#                         title    salary  years of experiences work type            what is your company city of company site date of salary city of company site        outlier_column                title_group
# 0              .net developer  311050.0                   2.0    Hybird                        Egyptian                Cairo     2024-02-01                cairo                salary             .net developer
# 1              .net developer  128000.0                   4.0    Hybird  Not Egyptian but site in egypt                Cairo     2024-02-01                cairo                salary             .net developer
# 2              .net developer  151000.0                   1.0   On Site                        Egyptian                Cairo     2024-02-01                cairo                salary             .net developer
# 3              .net developer  128000.0                   4.0    Hybird  Not Egyptian but site in egypt                Cairo     2024-02-01                cairo  years of experiences             .net developer
# 4              .net developer   37500.0                   7.0   On Site                        Egyptian           Alexandria     2024-02-01           alexandria  years of experiences             .net developer
# 5              .net developer   45000.0                   4.0    Hybird                        Egyption                Cairo     2024-02-25                cairo  years of experiences             .net developer
# 6              .net developer   30000.0                   4.0   On Site                        Egyption                Cairo     2024-02-01                cairo  years of experiences             .net developer
# 7                  accountant   18000.0                  10.0   On Site                        Egyption               Cairo      2024-02-23                cairo                salary                 accountant
# 8                  accountant   18000.0                  10.0   On Site                        Egyption               Cairo      2024-02-23                cairo  years of experiences                 accountant
# 9           android developer   50000.0                   5.0    Hybird                        Egyption                Cairo     1993-01-20                cairo                salary          android developer
# 10          backend developer   94000.0                   1.0    Hybird                        Egyptian                Cairo     2024-02-01                cairo                salary          backend developer
# 11          backend developer  139000.0                   5.0    Hybird  Not Egyptian but site in egypt                Cairo     2024-02-01                cairo                salary          backend developer
# 12          backend developer  139000.0                   5.0    Hybird  Not Egyptian but site in egypt                Cairo     2024-02-01                cairo  years of experiences          backend developer
# 13          backend developer   36000.0                   5.0  Remotley                        Egyptian                Cairo     2024-02-01                cairo  years of experiences          backend developer
# 14          backend developer   36000.0                   5.0  Remotley                        Egyption                Cairo     2023-03-01                cairo  years of experiences          backend developer
# 15            devops engineer   34000.0                   2.0  Remotley                        Egyption                Cairo     2023-01-30                cairo  years of experiences            devops engineer
# 16          dot net developer   53050.0                   7.0    Hybird                        Egyption                Cairo     2024-02-26                cairo                salary          dot net developer
# 17          dot net developer   53050.0                   7.0    Hybird                        Egyption                Cairo     2024-02-26                cairo  years of experiences          dot net developer
# 18          flutter developer   27500.0                   3.0    Hybird                        Egyption                cairo     2024-01-01                cairo                salary          flutter developer
# 19          flutter developer   25000.0                   3.0  Remotley                        Egyption               Cairo      2024-02-19                cairo                salary          flutter developer
# 20         frontend developer  225900.0                   2.0    Hybird                        Egyptian                Cairo     2024-02-01                cairo                salary         frontend developer
# 21         frontend developer  156000.0                   2.0   On Site                        Egyptian                Cairo     2024-02-01                cairo                salary         frontend developer
# 22         frontend developer  252000.0                   4.0   On Site  Not Egyptian but site in egypt                Cairo     2024-02-01                cairo                salary         frontend developer
# 23         frontend developer   30000.0                   7.0    Hybird                        Egyptian                 Giza     2024-02-01                 giza  years of experiences         frontend developer
# 24         frontend developer   65000.0                   7.0   On Site                        Egyptian        Smart Village     2024-02-01        smart village  years of experiences         frontend developer
# 25  full stack .net & angular   52000.0                   6.0    Hybird  Not Egyptian but site in egypt                Cairo     2024-02-01                cairo  years of experiences  full stack .net & angular
# 26  full stack .net developer  120000.0                   3.0  Remotley                        Egyptian       United Kingdom     2024-02-01       united kingdom                salary  full stack .net developer
# 27       full stack developer   95000.0                   2.0    Hybird                        Egyptian                Cairo     2024-02-01                cairo                salary       full stack developer
# 28       full stack developer  146000.0                   3.0   On Site                        Egyptian                Cairo     2024-02-01                cairo                salary       full stack developer
# 29       full stack developer    5000.0                   0.0   On Site                        Egyptian                Tanta     2024-02-01                tanta  years of experiences       full stack developer
# 30       full stack developer    7000.0                   8.0  Remotley                        Egyptian           Alexandria     2024-02-01           alexandria  years of experiences       full stack developer
# 31       full stack developer   30000.0                   6.0  Remotley                        Egyptian             un-known     2024-02-01             un-known  years of experiences       full stack developer
# 32       full stack developer   30000.0                   6.0  Remotley                        Egyption                  NaN     2024-01-02                  nan  years of experiences       full stack developer
# 33   full stack web developer    7000.0                   8.0  Remotley                        Egyption         Alex + Cairo     2024-02-27         alex + cairo  years of experiences   full stack web developer
# 34       full-stack developer   25000.0                   2.0    Hybird                        Egyptian                Cairo     2024-02-01                cairo                salary       full-stack developer
# 35       full-stack developer    5000.0                   2.0   On Site                        Egyption                Cairo     2024-02-01                cairo                salary       full-stack developer
# 36           graphic designer   10000.0                   9.0   On Site                        Egyption            Portsaid      2024-01-01             portsaid  years of experiences           graphic designer
# 37             java developer   81000.0                   1.0    Hybird                        Egyptian                Cairo     2024-02-01                cairo                salary             java developer
# 38             java developer   32000.0                   5.0    Hybird  Not Egyptian but site in egypt             un-known     2024-02-01             un-known  years of experiences             java developer
# 39             java developer    4000.0                   4.0  Remotley                        Egyptian                Cairo     2024-02-01                cairo  years of experiences             java developer
# 40             java developer   55000.0                   5.0    Hybird                        Egyption               Cairo      2024-03-07                cairo  years of experiences             java developer
# 41           network engineer   43000.0                  10.0   On Site                        Egyption               Cairo      2024-01-25                cairo                salary           network engineer
# 42           network engineer   43000.0                  10.0   On Site                        Egyption               Cairo      2024-01-25                cairo  years of experiences           network engineer
# 43           nodejs developer   85000.0                   2.0   On Site                        Egyptian       Kafr El Sheikh     2024-02-01       kafr el sheikh                salary           nodejs developer
# 44                 pharmacist    8700.0                   4.0   On Site                        Egyption                Cairo     2024-02-01                cairo                salary                 pharmacist
# 45              php developer  100000.0                  10.0   On Site                        Egyptian              El Doqy     2024-02-01              el doqy                salary              php developer
# 46              php developer  100000.0                  10.0   On Site                        Egyption              El Doqy     2050-12-20              el doqy                salary              php developer
# 47              php developer  100000.0                  10.0   On Site                        Egyptian              El Doqy     2024-02-01              el doqy  years of experiences              php developer
# 48              php developer  100000.0                  10.0   On Site                        Egyption              El Doqy     2050-12-20              el doqy  years of experiences              php developer
# 49            react developer   18000.0                   3.0   On Site                        Egyption                 Giza     2024-03-27                 giza                salary            react developer
# 50            react developer   18000.0                   3.0   On Site                        Egyption                 Giza     2024-03-27                 giza  years of experiences            react developer
# 51                      sales   50000.0                  10.0    Hybird                        Egyption               Cairo      2024-03-02                cairo                salary                      sales
# 52          software engineer    2800.0                   0.0  Remotley                        Egyption                Cairo     2022-09-01                cairo                salary          software engineer
# 53          software engineer   29000.0                   3.0   On Site                        Egyption                Cairo     2024-01-01                cairo                salary          software engineer
# 54          software engineer   12000.0                   0.0    Hybird                        Egyption               Cairo      2024-01-01                cairo                salary          software engineer

# %% [markdown]
# ###  Handling Outliers using IQR Clipping
#
# In this step, outliers were treated using the **IQR (Interquartile Range)** method with clipping instead of removal.
#
# - For each numerical column:
#   - Calculated Q1 (25th percentile) and Q3 (75th percentile)
#   - Computed IQR = Q3 - Q1
#   - Defined lower and upper bounds:
#     - Lower = Q1 - 1.5 * IQR
#     - Upper = Q3 + 1.5 * IQR
#
# - Values outside this range were **clipped** to the nearest boundary.
#
#  This approach preserves all data points while reducing the impact of extreme values.
#
#  Dataset shape remains unchanged before and after clipping.

# %%
import pandas as pd


df_fixed = df.copy()



num_cols = df_fixed.select_dtypes(include=['number']).columns


for col in num_cols:
    Q1 = df_fixed[col].quantile(0.25)
    Q3 = df_fixed[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df_fixed[col] = df_fixed[col].clip(lower, upper)


print("Before shape:", df.shape)
print("After fixing outliers:", df_fixed.shape)
# Out:
# Before shape: (854, 8)
# After fixing outliers: (854, 8)

# %% [markdown]
# ## comparison

# %%
import matplotlib.pyplot as plt

num_cols = df.select_dtypes(include=['number']).columns

for col in num_cols:
    plt.figure(figsize=(10,4))

    # =====================
    # BEFORE
    # =====================
    plt.subplot(1, 2, 1)
    df.boxplot(column=col)
    plt.title(f"Before - {col}")

    # =====================
    # AFTER
    # =====================
    plt.subplot(1, 2, 2)
    df_fixed.boxplot(column=col)
    plt.title(f"After - {col}")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Salary Statectics After Cleaning & Outlier Handling
#
# This section compares the **cleaned dataset** with the previous (less filtered) version to understand how removing noise and handling outliers affected the results.
#
# ---
#
# ## 1. Overall impact of cleaning
#
# After applying stronger cleaning and filtering:
# - Extreme salary values became more controlled in some roles
# - Distributions became more interpretable
# - Statistical measures (mean, std, skewness) became more stable in several job titles
#
# However, high variability still exists in many technical roles due to real market differences.
#
# ---
#
# ## 2. Changes in central tendency (Mean & Median)
#
# - The gap between mean and median is still present in most roles
# - This confirms that salary data is still **right-skewed**
# - Even after cleaning, high salaries still influence the average
#
# Example:
# - .NET Developer and Frontend Developer still show noticeable mean–median gaps
#
# ---
#
# ## 3. Skewness after cleaning
#
# - Skewness values are still **positive in most roles**
# - But they are more meaningful now because extreme noise was reduced
# - This means:
#   - Salaries are still concentrated in mid-range
#   - High earners still exist but are less distorted by errors/outliers
#
# ---
#
# ## 4. Variability (Standard deviation)
#
# - Standard deviation decreased in some roles after cleaning
# - But remains high in:
#   - Backend Developer
#   - Full Stack Developer
#   - NodeJS Developer
#
# This indicates:
# > Real market differences between junior, mid, and senior levels still strongly affect salary spread.
#
# ---
#
# ## 5. Key structural insight
#
#  After cleaning:
# - The dataset is not normally distributed
# - Salary distribution remains **heavily right-skewed**
# - Technical roles still show the highest dispersion and maximum values
#
# ---
#
# ## Final Conclusion
#
# After cleaning and handling outliers:
# - The data became more reliable and interpretable
# - Skewness is still positive but less distorted
# - Salary inequality across roles is a real pattern, not just noise
# - Technical roles continue to dominate in both salary level and variability

# %%
df_fixed.columns = df_fixed.columns.str.strip().str.lower()

df_fixed["title"] = df_fixed["title"].astype(str).str.lower().str.strip()
df_fixed["title"] = df_fixed["title"].replace("nan", "unknown")

df_fixed["salary"] = pd.to_numeric(df_fixed["salary"], errors="coerce")

df_fixed = df_fixed.dropna(subset=["salary"])

df_fixed = df_fixed[df_fixed["salary"] > 1000]

result = df_fixed.groupby("title")["salary"].agg([
    "mean","median","skew","max","min","count","std","var"
])

result = result[result["count"] >= 5]

result = result.sort_values(by="count", ascending=False)

print(result)
# Out:
#                                    mean   median      skew      max      min  count           std           var
# title
# .net developer             22766.666667  16000.0  0.484056  45125.0   5500.0     39  13650.813709  1.863447e+08
# frontend developer         24510.526316  20000.0  0.242505  45125.0   3500.0     38  16043.432006  2.573917e+08
# java developer             23693.750000  24250.0  0.226318  45125.0   4000.0     20  13935.558633  1.941998e+08
# php developer              20600.000000  13000.0  0.707204  45125.0   5000.0     20  16078.937678  2.585322e+08
# full stack developer       20078.947368  15000.0  0.849088  45125.0   5000.0     19  15081.158368  2.274413e+08
# flutter developer          11194.117647   8000.0  1.302798  27500.0   4000.0     17   7002.898560  4.904059e+07
# backend developer          25875.000000  21000.0  0.129409  45125.0   7000.0     14  13871.144648  1.924087e+08
# data analyst               12083.333333  12500.0  0.501880  24000.0   4500.0     12   5810.778908  3.376515e+07
# graphic designer            6590.909091   6500.0  0.164274  10000.0   3500.0     11   2142.640682  4.590909e+06
# full stack .net developer  16920.454545  15000.0  1.567887  45125.0   5000.0     11  11497.591151  1.321946e+08
# android developer          20212.500000  18000.0  1.374965  45125.0   7000.0     10  10882.269282  1.184238e+08
# nodejs developer           15112.500000  14000.0  2.585117  45125.0   7000.0     10  11107.500281  1.233766e+08
# data engineer              20222.222222  21000.0 -0.200049  30000.0  11000.0      9   6379.219736  4.069444e+07
# pharmacist                  4762.500000   4700.0  0.828539   8700.0   2000.0      8   2021.270817  4.085536e+06
# devops engineer            21862.500000  21000.0  0.060532  34000.0  10000.0      8   8277.842628  6.852268e+07
# accountant                  8950.000000   7750.0  1.682401  18000.0   5000.0      8   4219.681775  1.780571e+07
# software engineer          14975.000000  15000.0  0.490178  29000.0   2800.0      8   7119.741167  5.069071e+07
# data scientist             21714.285714  20000.0  0.302763  40000.0   7000.0      7  11441.361890  1.309048e+08
# machine learning engineer  21666.666667  19000.0  0.413484  35000.0  10000.0      6  11236.844160  1.262667e+08
# javascript developer       24800.000000  24000.0  0.196043  30000.0  20000.0      5   5019.960159  2.520000e+07
# full-stack developer       14600.000000  14000.0  0.280036  25000.0   5000.0      5   7092.249291  5.030000e+07
# medical representative      7700.000000   8000.0 -0.382400  10000.0   4500.0      5   2439.262184  5.950000e+06
# network engineer           18000.000000  10000.0  2.007235  43000.0  10000.0      5  14300.349646  2.045000e+08
# react developer            10400.000000  10000.0  1.492685  18000.0   6000.0      5   4560.701700  2.080000e+07
# software developer         16200.000000  12000.0  0.462552  27000.0   7000.0      5   9148.770409  8.370000e+07

# %% [markdown]
# ## Feature Engineering - Experience Level
#
# This code creates a new feature called **experience level** based on years of experience.
#
# - Explanation:
#
# If experience < 2 years → Junior
# If experience is between 2 and 4 years → Mid
# If experience ≥ 5 years → Senior
# - Result:
#
# A new categorical column is created to simplify and group employees based on experience level.

# %%
# Feature Engineering
df_fixed["experience level"] = df_fixed["years of experiences"].apply(
    lambda x: "Junior" if x < 2 else "Mid" if x < 5 else "Senior"
)

# %%
df.head()
# Out:
#             title    salary  years of experiences work type what is your company city of company site date of salary city of company site
# 0  .net developer   15000.0                   1.0    Hybird             Egyptian           Alexandria     2024-02-01           alexandria
# 1  .net developer  311050.0                   2.0    Hybird             Egyptian                Cairo     2024-02-01                cairo
# 2  .net developer   15000.0                   1.0    Hybird             Egyptian                 Giza     2024-02-01                 giza
# 3  .net developer   30000.0                   2.0    Hybird             Egyptian             Mansoura     2024-02-01             mansoura
# 4  .net developer   54000.0                   3.0    Hybird             Egyptian             un-known     2024-02-01             un-known

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Top Job Roles Visualization
#
#
# - A bar chart showing the top 10 most common job titles in the dataset.

# %%
top_roles = df["title"].value_counts().head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=top_roles.values, y=top_roles.index)
plt.title("Top Job Roles")
plt.show()

# %% [markdown]
# ## Job Roles Distribution (Pie Chart)
#
# - This visualization shows the percentage distribution of the top 5 job roles in the dataset.

# %%
roles = df["title"].value_counts().head(5)

plt.figure(figsize=(6,6))
plt.pie(roles, labels=roles.index, autopct='%1.1f%%')
plt.title("Job Roles Distribution")
plt.show()

# %% [markdown]
# ## Salary Distribution (Overall Range in Egypt)
#
# - This plot shows the overall distribution of salaries in the dataset, which reflects the salary range in Egypt based on the collected data.
# - Explanation:
#
# Shows how salaries are distributed across all records
#
# Helps identify the overall salary range in Egypt from the dataset
#
# kde=True gives a smooth curve to understand the trend better

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_fixed["salary"], bins=30, kde=True)
plt.title("Salary Distribution")
plt.show()

# %% [markdown]
# ## Salary by Job Title
#
# This visualization shows how salaries vary across different job titles in the dataset, helping to compare salary ranges between roles.

# %%
plt.figure(figsize=(12,6))

sns.boxplot(
    x="title",
    y="salary",
    data=df
)

plt.xticks(rotation=90)

plt.title("Salary by Job Title")
plt.xlabel("Job Title")
plt.ylabel("Salary")

plt.show()

# %% [markdown]
# ## Salary Distribution for Top 20 Job Titles
#
# This visualization shows the salary distribution only for the top 20 most frequent job titles in the dataset.
#
# Explanation:
# - Focuses only on the top 20 job roles
# - Makes the visualization clearer and less crowded compared to the full dataset
# - Helps better compare salary distributions for the most common positions
#
# Result:
#
# A simplified view of salary differences across the most frequent job titles.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_20_roles = df_fixed["title"].value_counts().head(20).index

df_top20 = df_fixed[df_fixed["title"].isin(top_20_roles)]

plt.figure(figsize=(12,6))
sns.boxplot(x="title", y="salary", data=df_top20)
plt.xticks(rotation=90)
plt.title("Salary Distribution for Top 20 Job Titles")
plt.show()

# %% [markdown]
# ## Salary vs Experience Correlation (Per Job Title)
#
# This analysis measures how salary changes with years of experience for the top 10 job titles, then visualizes the results using a heatmap.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df["salary"] = pd.to_numeric(df["salary"], errors="coerce")
df["years of experiences"] = pd.to_numeric(df["years of experiences"], errors="coerce")
df_clean = df.dropna(subset=["salary", "years of experiences", "title"])

top_jobs = df_clean["title"].value_counts().nlargest(10).index
df_top = df_clean[df_clean["title"].isin(top_jobs)]


corr_results = {}

for job in top_jobs:
    subset = df_top[df_top["title"] == job]
    
    if len(subset) > 1:  
        corr = subset["salary"].corr(subset["years of experiences"])
        corr_results[job] = corr

corr_df = pd.DataFrame.from_dict(corr_results, orient="index", columns=["Correlation"])

# =========================
# 4. Heatmap
# =========================
plt.figure(figsize=(6,5))
sns.heatmap(corr_df, annot=True, cmap="coolwarm", center=0, fmt=".2f")

plt.title("Salary vs Experience Correlation per Job")
plt.ylabel("Job Title")
plt.show()

# %% [markdown]
# ## Salary vs Experience Trend (Selected Roles)
#
# This analysis shows how the average salary changes with years of experience for specific job roles.

# %%
import matplotlib.pyplot as plt

roles = ["data scientist", "backend developer"]

for role in roles:
    df_role = df_fixed[df_fixed["title"] == role]

    if df_role.empty:
        continue

    avg_salary = df_role.groupby("years of experiences")["salary"].mean().sort_index()

    plt.figure(figsize=(6,4))
    plt.plot(avg_salary.index, avg_salary.values, marker='o')
    plt.title(f"Salary vs Experience - {role}")
    plt.xlabel("Years of Experience")
    plt.ylabel("Average Salary")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Salary Analysis by Role & Experience Level
#
# This analysis compares salaries across **4 main job roles** (Backend Developer, Data Scientist, Data Engineer, .NET Developer) and different experience levels (Junior, Mid, Senior).
#
# ---
#
# ###  Data Cleaning & Preparation
# - Standardized column names and job titles
# - Merged similar role names into unified categories
# - Cleaned salary values and removed invalid/outlier entries
# - Normalized experience levels into:
#   - Junior
#   - Mid
#   - Senior
#
# ---
#
# ###  Aggregated Analysis
# - Calculated **mean, median, and count** of salaries per (role + experience level)
# - Created a pivot table to compare median salaries across roles and experience levels
#
# ---
#
# ###  Visual Analysis
# Two visualizations were used:
# - **Bar Plot** → shows average salary comparison
# - **Box Plot** → shows salary distribution and spread per group
#
# ---
#
# ##  Key Insights
#
# ### 1. Experience strongly impacts salary
# - Salaries increase clearly from **Junior → Mid → Senior**
# - Senior level consistently has the highest salary range
#
# ---
#
# ### 2. Role differences exist
# - **Data Scientist** and **Data Engineer** tend to have higher median salaries
# - **Backend Developer** and **.NET Developer** are relatively closer in range
#
# ---
#
# ### 3. Salary variability increases with experience
# - Senior roles show wider salary ranges (more variability)
# - Junior roles are more stable and clustered
#
# ---
#
# ### 4. .NET Developer trend
# - More stable but slightly lower compared to data roles
# - Less variation in salary distribution
#
# ---
#
# ##  Conclusion
# - Experience is the strongest factor affecting salary
# - Data-related roles generally pay more than backend/.NET roles
# - Senior positions show both higher pay and higher variation

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df_fixed.columns = df_fixed.columns.str.strip().str.lower()

df_fixed["title"] = df_fixed["title"].astype(str).str.lower().str.strip()

df_fixed["title"] = df_fixed["title"].replace({
    "backend": "backend developer",
    "backend dev": "backend developer",
    "back-end developer": "backend developer",

    "data science": "data scientist",
    "data scientist ": "data scientist",

    "data engineer ": "data engineer",

    ".net": ".net developer",
    ".net developer ": ".net developer",
    ".net software developer": ".net developer",
    ".net backend developer": ".net developer",
    "dot net developer": ".net developer"
})

# =========================
df_fixed["salary"] = pd.to_numeric(df_fixed["salary"], errors="coerce")
df_fixed = df_fixed.dropna(subset=["salary"])
df_fixed = df_fixed[df_fixed["salary"] > 1000]


df_fixed["experience level"] = (
    df_fixed["experience level"]
    .astype(str)
    .str.lower()
    .str.strip()
)

df_fixed["experience level"] = df_fixed["experience level"].replace({
    "jr": "junior",
    "entry": "junior",
    "mid-level": "mid",
    "middle": "mid",
    "sr": "senior",
    "lead": "senior"
})

df_fixed = df_fixed[df_fixed["experience level"].isin(["junior","mid","senior"])]

roles = ["backend developer", "data scientist", "data engineer", ".net developer"]

df_roles = df_fixed[df_fixed["title"].isin(roles)]

print("\n=== Counts ===")
print(df_roles["title"].value_counts())


analysis = df_roles.groupby(
    ["title", "experience level"]
)["salary"].agg(["mean","median","count"]).reset_index()

print("\n=== Analysis ===")
print(analysis)


pivot = df_roles.pivot_table(
    values="salary",
    index="experience level",
    columns="title",
    aggfunc="median"
)

print("\n=== Pivot ===")
print(pivot)

# =========================
# 9. Bar Plot
# =========================
plt.figure(figsize=(10,6))
sns.barplot(data=df_roles, x="experience level", y="salary", hue="title")

plt.title("Salary Comparison by Experience Level (4 Roles)")
plt.show()

# =========================
# 10. Box Plot
# =========================
plt.figure(figsize=(10,6))
sns.boxplot(data=df_roles, x="experience level", y="salary", hue="title")

plt.title("Salary Distribution by Experience Level (4 Roles)")
plt.show()
# Out:
# === Counts ===
# title
# .net developer       44
# backend developer    15
# data engineer         9
# data scientist        7
# Name: count, dtype: int64
#
# === Analysis ===
#                title experience level          mean   median  count
# 0     .net developer           junior  16171.875000  12000.0     24
# 1     .net developer              mid  27848.611111  30000.0     18
# 2     .net developer           senior  41312.500000  41312.5      2
# 3  backend developer           junior  22569.444444  18000.0      9
# 4  backend developer              mid  20000.000000  20000.0      3
# 5  backend developer           senior  39041.666667  36000.0      3
# 6      data engineer           junior  18666.666667  21000.0      6
# 7      data engineer              mid  23333.333333  25000.0      3
# 8     data scientist           junior  16750.000000  15000.0      4
# 9     data scientist              mid  28333.333333  26000.0      3
#
# === Pivot ===
# title             .net developer  backend developer  data engineer  data scientist
# experience level
# junior                   12000.0            18000.0        21000.0         15000.0
# mid                      30000.0            20000.0        25000.0         26000.0
# senior                   41312.5            36000.0            NaN             NaN

# %% [markdown]
# ## Top Roles Salary Deep Dive (Filtered Analysis)
#
# This analysis focuses on **roles that appear at least 10 times** to ensure more reliable results, then compares salaries across experience levels.
#
# ---
#
# ###  What was done
# - Cleaned and standardized data (titles, salary, experience level)
# - Removed rare roles (kept only roles with ≥ 10 records)
# - Grouped data by **title + experience level**
# - Calculated mean, median, and count
# - Created pivot table for median salary comparison
# - Visualized top 10 roles using bar + box plots
#
# ---
#
# ##  Key Insights
#
# ### 1. More reliable comparison
# - After filtering, only **12 valid roles** remained
# - This makes the analysis more stable and less biased
#
# ---
#
# ### 2. Clear experience effect (again confirmed)
# - Junior → Mid → Senior shows consistent salary growth
# - Median values are more reliable than mean due to outliers
#
# ---
#
# ### 3. Highest paying roles
# - **.NET Developer** and **Android Developer** show strong senior-level salaries
# - **Frontend Developer** also shows strong growth with experience
# - **Data Analyst** and **Flutter Developer** are on the lower range
#
# ---
#
# ### 4. Data imbalance issue
# - Some senior roles have very few records (count = 1 or 2)
# - This makes senior-level insights less reliable for some jobs
#
# ---
#
# ### 5. Pivot table insight
# - Clearly shows salary hierarchy across roles
# - Helps compare roles at the same experience level directly
#
# ---
#
# ##   Conclusion
# - Experience is still the strongest driver of salary
# - Filtering improved clarity by removing noisy/rare roles
# - Tech roles vary significantly in salary depending on specialization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df_fixed.columns = df_fixed.columns.str.strip().str.lower()

df_fixed["title"] = df_fixed["title"].astype(str).str.lower().str.strip()

df_fixed["salary"] = pd.to_numeric(df_fixed["salary"], errors="coerce")
df_fixed = df_fixed.dropna(subset=["salary"])
df_fixed = df_fixed[df_fixed["salary"] > 1000]


df_fixed["experience level"] = (
    df_fixed["experience level"]
    .astype(str)
    .str.lower()
    .str.strip()
)

df_fixed["experience level"] = df_fixed["experience level"].replace({
    "jr": "junior",
    "entry": "junior",
    "mid-level": "mid",
    "middle": "mid",
    "sr": "senior",
    "lead": "senior"
})

df_fixed = df_fixed[df_fixed["experience level"].isin(["junior","mid","senior"])]


counts = df_fixed["title"].value_counts()

valid_roles = counts[counts >= 10].index  
df_roles = df_fixed[df_fixed["title"].isin(valid_roles)]

print("Number of roles:", len(valid_roles))


analysis = df_roles.groupby(
    ["title", "experience level"]
)["salary"].agg(["mean","median","count"]).reset_index()

print(analysis.head(20))


pivot = df_roles.pivot_table(
    values="salary",
    index="experience level",
    columns="title",
    aggfunc="median"
)

print(pivot)


top_roles = df_roles["title"].value_counts().head(10).index

df_top = df_roles[df_roles["title"].isin(top_roles)]

# Bar Plot
plt.figure(figsize=(12,6))
sns.barplot(data=df_top, x="experience level", y="salary", hue="title")
plt.title("Top 10 Roles - Salary vs Experience Level")
plt.xticks(rotation=0)
plt.show()

# Box Plot
plt.figure(figsize=(12,6))
sns.boxplot(data=df_top, x="experience level", y="salary", hue="title")
plt.title("Top 10 Roles - Salary Distribution")
plt.show()
# Out:
# Number of roles: 12
#                         title experience level          mean   median  count
# 0              .net developer           junior  16171.875000  12000.0     24
# 1              .net developer              mid  27848.611111  30000.0     18
# 2              .net developer           senior  41312.500000  41312.5      2
# 3           android developer           junior  12500.000000  12500.0      2
# 4           android developer              mid  18857.142857  20000.0      7
# 5           android developer           senior  45125.000000  45125.0      1
# 6           backend developer           junior  22569.444444  18000.0      9
# 7           backend developer              mid  20000.000000  20000.0      3
# 8           backend developer           senior  39041.666667  36000.0      3
# 9                data analyst           junior  12642.857143  13000.0      7
# 10               data analyst              mid  11300.000000  10000.0      5
# 11          flutter developer           junior   8111.111111   8000.0      9
# 12          flutter developer              mid  14662.500000  14000.0      8
# 13         frontend developer           junior  16203.846154   9000.0     13
# 14         frontend developer              mid  28070.652174  25000.0     23
# 15         frontend developer           senior  37562.500000  37562.5      2
# 16  full stack .net developer           junior  13875.000000  11500.0      8
# 17  full stack .net developer              mid  25041.666667  15000.0      3
# 18       full stack developer           junior  10000.000000  11000.0      3
# 19       full stack developer              mid  21884.615385  15000.0     13
# title             .net developer  android developer  backend developer  data analyst  flutter developer  frontend developer  full stack .net developer  full stack developer  graphic designer  java developer  nodejs developer  php developer
# experience level
# junior                   12000.0            12500.0            18000.0       13000.0             8000.0              9000.0                    11500.0               11000.0            5250.0         24500.0            9000.0         8250.0
# mid                      30000.0            20000.0            20000.0       10000.0            14000.0             25000.0                    15000.0               15000.0            6000.0         13500.0           16000.0        19500.0
# senior                   41312.5            45125.0            36000.0           NaN                NaN             37562.5                        NaN               30000.0            8750.0         38562.5               NaN        45125.0

# %% [markdown]
# ## Hypothesis
# ## Salary Differences Between Job Roles (ANOVA Test)
#
# This test checks whether there are statistically significant differences in salaries between different job roles.
#
# Results
# - F-statistic: 0.3571
# - P-value: 0.7842
# -- Interpretation
#
# Since p-value > 0.05
#
#  We fail to reject the null hypothesis
#
# This means there is no statistically significant difference in salaries between the selected job roles in this dataset
#
#  Conclusion
#
# Even though salaries may look different visually in plots, statistically the differences between these roles are not significant in this dataset.

# %%
from scipy.stats import f_oneway

roles = ["backend developer", "data scientist", "data engineer", ".net developer"]

groups = []

for role in roles:
    group = df_fixed[df_fixed["title"] == role]["salary"].dropna()
    groups.append(group)

# ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("P-value:", p_value)
# Out:
# F-statistic: 0.357086101261026
# P-value: 0.7841534940073881

# %% [markdown]
# ## ANOVA After Fixing Experience Mixing Issue
#
# After the previous ANOVA test, we suspected that the results might be misleading because we were mixing different experience levels together.
# So, we repeated the test by separating the data based on **experience level**.
#
# #### Result
#
# “No statistically significant difference was found between job roles within each experience level, possibly due to overlapping salary distributions and limited sample sizes in some groups.”

# %%
from scipy.stats import f_oneway

experiences = ["junior", "mid", "senior"]

for exp in experiences:
    print(f"\n=== {exp.upper()} LEVEL ===")
    
    subset = df_fixed[df_fixed["experience level"] == exp]

    roles = ["backend developer", "data scientist", "data engineer", ".net developer"]
    
    groups = []
    
    for role in roles:
        group = subset[subset["title"] == role]["salary"].dropna()
        
        if len(group) > 1:
            groups.append(group)

  
    if len(groups) >= 2:
        f_stat, p_value = f_oneway(*groups)

        print("F-statistic:", f_stat)
        print("P-value:", p_value)

        if p_value < 0.05:
            print(" Significant difference between roles")
        else:
            print(" No significant difference between roles")
    else:
        print("Not enough data for ANOVA")
# Out:
# === JUNIOR LEVEL ===
# F-statistic: 0.6750478306164279
# P-value: 0.5725615391543569
# 👉 No significant difference between roles
#
# === MID LEVEL ===
# F-statistic: 0.4554921156206573
# P-value: 0.7159674489295059
# 👉 No significant difference between roles
#
# === SENIOR LEVEL ===
# F-statistic: 0.21948335847778563
# P-value: 0.6713734202700884
# 👉 No significant difference between roles

# %% [markdown]
# ## Cohen’s d (Effect Size Analysis)
#
# After performing ANOVA, which tests whether there is a statistically significant difference between job roles, we applied **Cohen’s d** to measure the **strength (magnitude) of the difference** between two groups.
#
# Unlike ANOVA, which only tells us whether a difference exists or not, Cohen’s d helps us understand **how large or small that difference actually is in practice**.
#
# ---
#
# ###  Result:
# - Cohen’s d = **-0.3057**
#
# ---
#
# ##  Interpretation
# - The value is close to 0
# - This indicates a **small effect size**
# - The negative sign only shows the direction of the difference (which group has a slightly higher mean)
#
# ---
#
# ##  Conclusion
# Although ANOVA suggested no statistically significant difference between roles, Cohen’s d confirms that even if a difference exists, it is **small and not practically meaningful** in this dataset.

# %%
import numpy as np

def cohens_d(x, y):
    return (np.mean(x) - np.mean(y)) / np.sqrt((np.std(x)**2 + np.std(y)**2) / 2)

ds = df_fixed[df_fixed["title"]=="data scientist"]["salary"]
be = df_fixed[df_fixed["title"]=="backend developer"]["salary"]

print(cohens_d(ds, be))
# Out:
# -0.305739809203681

# %% [markdown]
# ## Confidence Intervals for Salary by Job Title
# ### Why we did this
#
# After comparing salaries using ANOVA and Cohen’s d, we wanted a more interpretable statistical range instead of just averages.
# So we used Confidence Intervals to understand the uncertainty around each job’s average salary.
#
# ### What the results show
#
# Each job title has a mean salary and a range (CI lower → CI upper)
# The CI shows where the true average salary is likely to fall with 95% confidence
#
# ### Key Insights
# 1. Highest paying roles
#
# Backend Developer, Java Developer, and Frontend Developer are among the highest average salaries
# They also have relatively wide ranges, meaning salary variability is high
#
# 2. Tech vs non-tech gap
#
# Technical roles (Software, Backend, ML, Data Science) generally have higher salaries
# Non-technical roles (Accountant, Pharmacist, Graphic Designer) are at the lower end
#
# 3. Salary uncertainty
# Some roles like Machine Learning Engineer and Data Scientist have wide confidence intervals
#
#  This means salaries are not very stable and vary a lot
#
# 4. Data quality insight
# Roles with fewer records show wider confidence intervals
#
#  meaning less reliable estimates
#
# ### Final Conclusion
#
# Confidence intervals show that while there are clear differences in average salaries between roles, there is also a high level of variation within each role, especially in tech-related jobs.
#
# This helps us understand not just the salary level, but also how stable or variable each job’s salary is in the market.

# %%
import scipy.stats as st

ci_results = []

for role in df_fixed["title"].unique():
    data = df_fixed[df_fixed["title"] == role]["salary"].dropna()
    
    if len(data) < 5:
        continue

    mean = data.mean()
    ci = st.t.interval(0.95, len(data)-1, loc=mean, scale=st.sem(data))

    ci_results.append({
        "title": role,
        "mean": mean,
        "ci_lower": ci[0],
        "ci_upper": ci[1]
    })

ci_df = pd.DataFrame(ci_results)
ci_df.sort_values("mean", ascending=False)
# Out:
#                         title          mean      ci_lower      ci_upper
# 1           backend developer  25350.000000  17862.686094  32837.313906
# 7        javascript developer  24800.000000  18566.896198  31033.103802
# 2          frontend developer  24510.526316  19237.181437  29783.871194
# 6              java developer  23693.750000  17171.707798  30215.792202
# 0              .net developer  22091.477273  17874.812387  26308.142158
# 11            devops engineer  21862.500000  14942.050377  28782.949623
# 16             data scientist  21714.285714  11132.790815  32295.780613
# 18  machine learning engineer  21666.666667   9874.321926  33459.011408
# 9               php developer  20600.000000  13074.825527  28125.174473
# 19              data engineer  20222.222222  15318.719858  25125.724586
# 10          android developer  20212.500000  12427.793517  27997.206483
# 4        full stack developer  20078.947368  12810.061712  27347.833025
# 21           network engineer  18000.000000    243.770683  35756.229317
# 3   full stack .net developer  16920.454545   9196.267709  24644.641382
# 17         software developer  16200.000000   4840.301155  27559.698845
# 8            nodejs developer  15112.500000   7166.672966  23058.327034
# 15          software engineer  14975.000000   9022.747428  20927.252572
# 5        full-stack developer  14600.000000   5793.809390  23406.190610
# 12               data analyst  12083.333333   8391.340556  15775.326111
# 13          flutter developer  11194.117647   7593.559448  14794.675846
# 14            react developer  10400.000000   4737.140892  16062.859108
# 24                 accountant   8950.000000   5422.257753  12477.742247
# 23     medical representative   7700.000000   4671.255965  10728.744035
# 20           graphic designer   6590.909091   5151.463495   8030.354687
# 22                 pharmacist   4762.500000   3072.675309   6452.324691

# %% [markdown]
# ## Career Growth Rate (Junior → Senior)
#
# ### Why we did this
#
# Instead of just comparing salaries at one level, we wanted to measure:
#
# How much does a job grow financially with experience?
#
# So we calculated the percentage growth from Junior to Senior for each role.
#
# ## What the results show
# Each row represents a job title
# junior vs senior shows starting vs advanced salary
# growth_rate shows how much salary increases in percentage
# ## Key Insights
#
# ### 1. Highest growth roles
# Some roles show very high salary growth (over 300%–600%)
# Example: Full Stack .NET & Angular, Sales, PHP Developer
#
#  These roles have strong financial progression with experience
#
# ### 2. Stable growth roles
#
# Backend Developer, Accountant, Graphic Designer
#
#  Show moderate but consistent growth (around 60%–100%)
#
# “Some roles show unstable or irregular growth patterns due to limited samples or natural variability in salary progression.”
#
# ###Final Conclusion
#
# This analysis highlights that career progression impact is not equal across all roles.
# Some jobs reward experience with very high salary growth, while others show weak or inconsistent progression.
#
#  This helps identify which careers have better long-term financial growth potential.

# %%
growth = df_fixed.groupby(["title","experience level"])["salary"].median().unstack()

growth = growth.dropna(subset=["junior", "senior"])

growth["growth_rate"] = (
    (growth["senior"] - growth["junior"]) / growth["junior"] * 100
)

growth = growth.sort_values("growth_rate", ascending=False)

growth
# Out:
# experience level            junior      mid   senior  growth_rate
# title
# full stack .net & angular   6000.0  18000.0  45125.0   652.083333
# sales                       4500.0      NaN  27562.5   512.500000
# php developer               8250.0  19500.0  45125.0   446.969697
# frontend developer          9000.0  25000.0  37562.5   317.361111
# civil engineer              5000.0      NaN  20000.0   300.000000
# front-end developer         8000.0      NaN  30000.0   275.000000
# android developer          12500.0  20000.0  45125.0   261.000000
# .net developer             12000.0  30000.0  41312.5   244.270833
# full stack developer       11000.0  15000.0  30000.0   172.727273
# network engineer           10000.0  13500.0  26500.0   165.000000
# backend developer          18000.0  20000.0  36000.0   100.000000
# accountant                  7550.0   6750.0  15000.0    98.675497
# graphic designer            5250.0   6000.0   8750.0    66.666667
# medical representative      6000.0   8000.0  10000.0    66.666667
# java developer             24500.0  13500.0  38562.5    57.397959
# odoo developer             14000.0      NaN  21000.0    50.000000
# pharmacist                  3700.0   6850.0   4500.0    21.621622
# technical office engineer   8000.0      NaN   8000.0     0.000000
# full stack web developer    7500.0   8000.0   7000.0    -6.666667
# php                         8000.0      NaN   4500.0   -43.750000

# %% [markdown]
# ## Best Paying City per Job Role (Egypt Analysis)
#
# This analysis identifies the **highest-paying city for each job title** based on median salary.
#
# ---
#
# ###  What was done
# - Cleaned and standardized job titles and city names
# - Removed invalid salary values and outliers
# - Grouped data by **job title + city**
# - Calculated **median salary per group**
# - Kept only groups with enough data (≥ 3 records)
# - Selected the city with the **highest median salary for each job**
#
# ---
#
# ##  Results Overview
# The table shows:
# - **Rank** → position based on salary
# - **Job Title**
# - **Best Paying City**
# - **Median Salary**
#
# ---
#
# ##  Key Insights
#
# ### 1. Cairo dominates the job market
# - Most high-paying roles are concentrated in **Cairo**
# - Especially for:
#   - Backend Developer
#   - Software Engineer
#   - Data roles (Data Scientist, Data Engineer)
#
# ---
#
# ### 2. Highest paying combinations
# - Backend Developer (Django) in Cairo → **highest median salary**
# - Senior Software Engineer also at the top level
# - Frontend Engineer and Backend roles follow closely
#
# ---
#
# ### 3. “Unknown” city entries
# - Some roles show **“unknown” location**
# - These still have relatively high salaries
# - Might indicate:
#   - Remote jobs
#   - Missing location data
#
# ---
#
# ### 4. Data insight
# - Tech roles consistently outperform others across cities
# - Location still matters, but **role is the stronger factor**
#
# ---
#
# ##  Final Conclusion
# This analysis shows that **Cairo is the main hub for high-paying tech jobs in Egypt**, but the job role itself has a stronger impact on salary than location in most cases.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# =========================
# 0. Copy + Remove duplicate columns
# =========================
df = df_fixed.copy()
df = df.loc[:, ~df.columns.duplicated()]

# =========================
# 1. Normalize column names
# =========================
df.columns = df.columns.str.strip().str.lower()

# =========================
# 2. Clean text columns safely
# =========================
df["title"] = df["title"].astype(str).str.lower().str.strip()
df["city of company site"] = df["city of company site"].astype(str).str.lower().str.strip()

# =========================
# 3. Clean salary
# =========================
df["salary"] = pd.to_numeric(df["salary"], errors="coerce")
df = df.dropna(subset=["salary"])
df = df[df["salary"] > 1000]

# =========================
# 4. Group by (job + city)
# =========================
job_city = df.groupby(
    ["title", "city of company site"],
    as_index=False
)["salary"].agg(["median", "count"]).reset_index()

# =========================
# 5. Remove small samples
# =========================
job_city = job_city[job_city["count"] >= 3]

# =========================
# 6. Best city per job
# =========================
best_city = job_city.loc[
    job_city.groupby("title")["median"].idxmax()
]

best_city = best_city.sort_values("median", ascending=False)

best_city["rank"] = range(1, len(best_city) + 1)

best_city = best_city[["rank", "title", "city of company site", "median"]]

# =========================
# 7. Display table
# =========================
print("=== Best Paying City per Job Role ===\n")
display(best_city.head(20).reset_index(drop=True))

# =========================
# 8. Visualization
# =========================
top10 = best_city.head(10)

plt.figure(figsize=(12,6))

plt.barh(
    top10["title"] + " | " + top10["city of company site"],
    top10["median"]
)

plt.title("Top 10 Highest Paying Job-City Combinations (Egypt)")
plt.xlabel("Median Salary")
plt.gca().invert_yaxis()

plt.show()
# Out:
# === Best Paying City per Job Role ===
#     rank                       title city of company site   median
# 0      1  backend developer - django                cairo  45125.0
# 1      2    senior software engineer                cairo  45125.0
# 2      3           frontend engineer                cairo  40000.0
# 3      4          frontend developer             un-known  31812.5
# 4      5              .net developer             un-known  28500.0
# 5      6           backend developer                cairo  28000.0
# 6      7             devops engineer                cairo  25000.0
# 7      8              java developer                cairo  24750.0
# 8      9               data engineer                cairo  23500.0
# 9     10              data scientist                cairo  20000.0
# 10    11        javascript developer                cairo  20000.0
# 11    12               ios developer                cairo  18500.0
# 12    13               php developer                cairo  17000.0
# 13    14           android developer                cairo  16500.0
# 14    15            nodejs developer                cairo  15000.0
# 15    16           software engineer                cairo  15000.0
# 16    17   machine learning engineer                cairo  15000.0
# 17    18        full stack developer                cairo  15000.0
# 18    19        full-stack developer                cairo  14000.0
# 19    20         wordpress developer                cairo  14000.0

# %% [markdown]
# ## Job Roles vs Cities Salary Heatmap
#
# This heatmap shows how median salaries are distributed across the top job roles and top cities in Egypt.
#
# ---
#
# ###  What this step does
# - Selects the most frequent 10 job roles and 8 cities
# - Computes median salary for each (role × city) pair
# - Applies log scaling to make values more comparable
# - Visualizes the final matrix using a heatmap
#
# ---
#
# ##  Insights
#
# ### 1. Salary concentration
# High values are mainly concentrated in a few role–city combinations, while most cells show lower or missing values.
#
# ---
#
# ### 2. Cairo dominance
# Cairo appears frequently in higher salary positions across multiple roles.
#
# ---
#
# ### 3. Role vs location
# Differences between roles are more noticeable than differences between cities in most cases.
#
# ---
#
# ### 4. Data distribution
# The wide range of values required log scaling, indicating strong imbalance in salary distribution.
#
# ---
#
# ##  Conclusion
# The heatmap provides a comparative view of salary distribution across roles and cities, highlighting concentration in specific combinations rather than uniform distribution.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# =========================
# 0. Copy + Remove duplicate columns 
# =========================
df = df_fixed.copy()
df = df.loc[:, ~df.columns.duplicated()]

# =========================
# 1. Normalize column names
# =========================
df.columns = df.columns.str.strip().str.lower()

# =========================
# 2. Clean safely 
# =========================
df["title"] = df["title"].astype(str).str.lower().str.strip()

df["city of company site"] = df["city of company site"].astype(str).str.lower().str.strip()

# =========================
# 3. Clean salary
# =========================
df["salary"] = pd.to_numeric(df["salary"], errors="coerce")
df = df.dropna(subset=["salary"])

# =========================
# 4. Top jobs & cities
# =========================
top_jobs = df["title"].value_counts().head(10).index
top_cities = df["city of company site"].value_counts().head(8).index

# =========================
# 5. Heatmap data
# =========================
heatmap_data = df[
    df["title"].isin(top_jobs) &
    df["city of company site"].isin(top_cities)
].groupby(
    ["title", "city of company site"]
)["salary"].median().unstack()

# =========================
# 6. Clean + scale
# =========================
heatmap_data = heatmap_data.fillna(0)
heatmap_data = np.log1p(heatmap_data)

# =========================
# 7. Sorting
# =========================
heatmap_data = heatmap_data.loc[
    heatmap_data.mean(axis=1).sort_values(ascending=False).index
]

# =========================
# 8. Plot
# =========================
plt.figure(figsize=(14,7))

sns.heatmap(
    heatmap_data,
    cmap="coolwarm",
    linewidths=0.5,
    linecolor="white",
    annot=False
)

plt.title(" Ranking Heatmap: Top Job Roles vs Top Cities (Egypt)", fontsize=14)
plt.xlabel("City")
plt.ylabel("Job Title")

plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ruof\AppData\Local\Temp\ipykernel_13548\3352055142.py:79: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Ruof\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
